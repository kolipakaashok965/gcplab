# %% [markdown]
# We will build a Linear regression model for Medical cost dataset. The dataset consists of age, sex, BMI(body mass index), children, smoker and region feature, which are independent and charge as a dependent feature. We will predict individual medical costs billed by health insurance.

# %% [markdown]
# ## Import Library and Dataset
# Now we will import couple of python library required for our analysis and import dataset

# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization
plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
plt.style.use('seaborn-whitegrid')

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Import dataset
#path ='dataset/'
#path = '../input/'
df = pd.read_csv('insurance.csv')
print('\nNumber of rows and columns in the data set: ',df.shape)
print('')

#Lets look into top few rows and columns in the dataset
df.head()
# Out:
# ('\nNumber of rows and columns in the data set: ', (1338, 7))
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
req_cols=['bmi','age','charges']
df=df[req_cols].copy()

#df[['bmi','age','charges']]

# %%
df_copy=df.copy()

# %%
X = df.drop('charges',axis=1) # Independet variable
y = df['charges'] # dependent variable

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=23)

# %%
# Scikit Learn module

lin_reg = LinearRegression()
model=lin_reg.fit(X_train,y_train) # Note: x_0 =1 is no need to add, sklearn will take care of it.

# #Parameter
# sk_theta = [lin_reg.intercept_]+list(lin_reg.coef_)
# parameter_df = parameter_df.join(pd.Series(sk_theta, name='Sklearn_theta'))
# parameter_df

# %%
model.predict(X_test)
# Out:
# array([17578.2470306 , 10365.0231741 , 11334.43625042, 14701.53359476,
#        13764.59559544, 13774.84595761, 16889.46573297, 13600.95997084,
#        16935.98907412, 20429.15062568,  7574.47764178, 17800.32266757,
#         9265.30218735, 17324.37437654, 14003.21896015, 11101.29657939,
#         9624.00258296,  8711.59546864, 17217.02768876, 14373.66144973,
#        20319.32395696, 17919.10126008, 12589.24777393, 15784.30001782,
#        17176.95680781, 11561.12346127, 10200.96123092, 10952.05760698,
#         6031.88433684, 17147.81434893, 19858.08250734, 11040.47323277,
#         8850.87478549, 17526.68579699, 14005.17597581, 11153.69096752,
#        14632.7465735 , 15089.89941454, 13974.79352645,  9040.57199217,
#        15584.64315557, 14337.09776415, 14952.32537203, 11906.51210055,
#        16548.72763284, 19357.6033313 ,  9250.45973395,  9421.67167986,
#        14373.1190018 ,  9162.76113335, 19178.27261613, 13944.93404239,
#        16203.49408818, 10868.13742572, 10961.45533198, 19861.4346081 ,
#        20817.5359281 , 16789.69536652, 12235.06230549,  8901.71899391,
#        12215.43370096, 12003.02701295,  9798.547147  , 11178.06675791,
#         8928.20689458, 11568.13785202, 11201.02798057, 10840.39005193,
#         9040.99831075,  6619.50018292, 11654.44136753, 14752.80412176,
#        12946.80482577, 11005.88604548,  8409.24245777, 11863.47647214,
#        14234.13039156,  8400.98807654, 11939.6847201 ,  9864.97031664,
